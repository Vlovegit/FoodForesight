# %%
#Generate new random orders for a pantry for past n years

import csv
import random
import datetime
import pandas as pd

# Constants for food size ranges
SIZE_RANGES = {
    "Small": (4000, 6000),
    "Medium": (6000, 8000),
    "Large": (8000, 9000)
}

# read the data from the excel file
df = pd.read_excel("DataModel.xlsx", sheet_name="Pantry")

# Group the pantries by ID and size
pantries = {}
for idx, row in df.iterrows():
    if row['PantryName'] != 'PantryName':
        pantry_id = row['PantryID']
        size = row['Size']
        if pantry_id not in pantries:
            pantries[pantry_id] = {}
        if size not in pantries[pantry_id]:
            pantries[pantry_id][size] = []
        pantries[pantry_id][size].append(row.to_dict())

# Generate food requests for each pantry and size
food_reqs = []
for pantry_id in pantries:
    for size in pantries[pantry_id]:
        rows = pantries[pantry_id][size]
        for i in range(random.randint(50, 80)):
            order_date = pd.to_datetime('now') - pd.Timedelta(days=random.randint(1, 730))
            delivery_date = order_date + pd.Timedelta(days=random.randint(4, 7))
            delivery_time = (pd.Timestamp.today().replace(hour=9, minute=0, second=0) + pd.Timedelta(hours=random.randint(0, 9))).strftime('%I:%M %p')
            order_date = order_date.strftime('%m-%d-%Y')
            delivery_date = delivery_date.strftime('%m-%d-%Y')
            quantity = random.randint(SIZE_RANGES[size][0], SIZE_RANGES[size][1])
            random_number = random.randint(100000, 900000)
            orderId = 'AFCBO' + str(random_number)
            food_reqs.append({'OrderId': orderId, 'PantryID': pantry_id, 'Order_Date': order_date, 'Delivery_Date': delivery_date, 'Delivery_Time': delivery_time, 'Quantity': quantity})

# Create a pandas DataFrame from the food requests
df_food_reqs = pd.DataFrame(food_reqs)

with pd.ExcelWriter("DataModel.xlsx", mode="a") as writer:
    df_food_reqs.to_excel(writer, sheet_name="FoodOrders", index=False)
# Out:
# <ipython-input-161-896ce41a5635>:34: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   order_date = pd.to_datetime('now') - pd.Timedelta(days=random.randint(1, 730))

# %%
#Add list of random items to the order basket for all orders

import pandas as pd
import random

# Read the input Excel file and select the FoodOrders2 sheet
df = pd.read_excel('DataModel.xlsx', sheet_name='FoodOrders')

# Choose random items from the list of 50 and concatenate them
items = []
for i in range(df.shape[0]):
    items = []
    for j in range(random.randint(20, 50)):
        items.append(random.choice([
            'Canned vegetables',
            'Canned fruits',
            'Canned beans',
            'Rice',
            'Pasta',
            'Canned soup',
            'Cereal',
            'Oatmeal',
            'Peanut butter',
            'Jelly or jam',
            'Canned tuna or chicken',
            'Canned chili',
            'Tomato sauce',
            'Macaroni and cheese',
            'Boxed potatoes',
            'Boxed stuffing mix',
            'Boxed cake mix',
            'Granola bars',
            'Crackers',
            'Chips',
            'Pretzels',
            'Popcorn',
            'Trail mix',
            'Nuts',
            'Dried fruit',
            'Fruit cups',
            'Pudding cups',
            'Jello cups',
            'Shelf-stable milk',
            'Evaporated milk',
            'Condensed milk',
            'Instant coffee',
            'Tea bags',
            'Hot cocoa mix',
            'Sugar',
            'Flour',
            'Baking powder',
            'Baking soda',
            'Vanilla extract',
            'Cooking oil',
            'Vinegar',
            'Ketchup',
            'Mustard',
            'Mayonnaise',
            'Salad dressing',
            'Spices',
            'Condiments',
            'Canned spaghetti or ravioli',
            'Instant mashed potatoes',
            'Pancake mix and syrup'
        ]))
    items = list(set(items))   
    item_str = ', '.join(items)

    # Add a column to the DataFrame with the items
    df.loc[i, 'Items'] = item_str

# Write the updated DataFrame to a new sheet in the Excel file
with pd.ExcelWriter('DataModel.xlsx', engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    df.to_excel(writer, sheet_name='FoodOrders', index=False)

# %%
#Find the most popular basket for an order for all Pantries

import pandas as pd

# read the data from the excel file
df = pd.read_excel("DataModel.xlsx", sheet_name="FoodOrders")

# split the items column into a list of items for each row
df["Items"] = df["Items"].str.split(", ")

# create a new dataframe to store the top 15 items for each pantry
top_items_df = pd.DataFrame(columns=["PantryId", "TopItems"])

# loop over each unique pantry ID
for pantry_id in df["PantryID"].unique():
    
    # filter the dataframe to only include rows with the current pantry ID
    pantry_df = df[df["PantryID"] == pantry_id]
    
    # create a dictionary to store the frequency count of each item for the current pantry
    item_counts = {}
    
    # loop over each row in the filtered dataframe
    for index, row in pantry_df.iterrows():
        #print(row["Items"])
        # loop over each item in the current row
        for item in row["Items"]:
            
            # add the item to the dictionary if it doesn't exist, and increment the count if it does
            if item not in item_counts:
                item_counts[item] = 1
            else:
                item_counts[item] += 1
    
    # sort the items by their frequency count in descending order
    sorted_items = sorted(item_counts.items(), key=lambda x: x[1], reverse=True)
    
    # take the top 15 items and store them in a list
    top_items = [item[0] for item in sorted_items[:15]]

    # Convert the list of top items to a comma-separated string
    top_items_str = ', '.join([x for x in top_items])
    
    # add the pantry ID and top 15 items to the new dataframe
    top_items_df = top_items_df.append({"PantryID": pantry_id, "TopItems": top_items_str}, ignore_index=True)

# save the top items dataframe to a new sheet in the same excel file
with pd.ExcelWriter("DataModel.xlsx", mode="a") as writer:
    top_items_df.to_excel(writer, sheet_name="TopItems", index=False)
# Out:
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Granola bars', 'Canned chili', 'Crackers', 'Ketchup', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Trail mix', 'Macaroni and cheese', 'Shelf-stable milk', 'Rice', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Pudding cups', 'Pasta', 'Popcorn', 'Crackers', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Cereal', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Vinegar', 'Nuts', 'Trail mix', 'Boxed cake mix', 'Tomato sauce', 'Pretzels', 'Condiments', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Popcorn', 'Crackers', 'Dried fruit', 'Oatmeal', 'Canned tuna or chicken', 'Salad dressing', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Hot cocoa mix', 'Canned fruits']
# ['Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Jello cups', 'Instant coffee', 'Vinegar', 'Chips', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Pretzels', 'Condiments', 'Hot cocoa mix']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pasta', 'Crackers', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Canned soup', 'Trail mix', 'Macaroni and cheese', 'Rice', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Crackers', 'Canned beans', 'Jelly or jam', 'Oatmeal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Flour', 'Instant coffee', 'Mustard', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Rice', 'Hot cocoa mix']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Canned chili', 'Ketchup', 'Canned beans', 'Cooking oil', 'Cereal', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Vinegar', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Canned chili', 'Tea bags', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Oatmeal', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Chips', 'Trail mix', 'Canned soup', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Boxed stuffing mix', 'Pudding cups', 'Pasta', 'Tea bags', 'Popcorn', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Boxed potatoes', 'Baking soda', 'Canned tuna or chicken', 'Salad dressing', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Hot cocoa mix', 'Canned fruits']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Tea bags', 'Crackers', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Salad dressing', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Baking powder', 'Mustard', 'Canned soup', 'Trail mix', 'Tomato sauce', 'Rice', 'Canned fruits']
# ['Condensed milk', 'Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Boxed potatoes', 'Sugar', 'Salad dressing', 'Flour', 'Instant coffee', 'Baking powder', 'Nuts', 'Chips', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Rice', 'Condiments', 'Canned fruits']
# ['Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Dried fruit', 'Cooking oil', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Rice', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Pudding cups', 'Boxed stuffing mix', 'Pasta', 'Tea bags', 'Crackers', 'Ketchup', 'Peanut butter', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Canned vegetables', 'Boxed potatoes', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Pretzels', 'Condiments', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Canned chili', 'Crackers', 'Peanut butter', 'Evaporated milk', 'Vanilla extract', 'Jelly or jam', 'Canned tuna or chicken', 'Instant mashed potatoes', 'Nuts', 'Chips', 'Macaroni and cheese', 'Boxed cake mix', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Popcorn', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned tuna or chicken', 'Sugar', 'Salad dressing', 'Jello cups', 'Instant mashed potatoes', 'Vinegar', 'Canned soup', 'Boxed cake mix', 'Rice', 'Tomato sauce', 'Condiments', 'Canned fruits']
# ['Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Tea bags', 'Popcorn', 'Ketchup', 'Evaporated milk', 'Cooking oil', 'Jelly or jam', 'Spices', 'Baking soda', 'Boxed potatoes', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Vinegar', 'Nuts', 'Trail mix', 'Canned soup', 'Canned spaghetti or ravioli', 'Rice']
# ['Mayonnaise', 'Canned chili', 'Tea bags', 'Popcorn', 'Ketchup', 'Peanut butter', 'Vanilla extract', 'Jelly or jam', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Trail mix', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Condiments', 'Hot cocoa mix']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Evaporated milk', 'Canned beans', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Pancake mix and syrup', 'Jello cups', 'Baking powder', 'Mustard', 'Nuts', 'Vinegar', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Rice', 'Condiments']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Crackers', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Vinegar', 'Canned soup', 'Macaroni and cheese', 'Pretzels', 'Tomato sauce', 'Condiments', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Tea bags', 'Popcorn', 'Evaporated milk', 'Canned beans', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Flour', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Chips', 'Trail mix', 'Boxed cake mix', 'Rice', 'Condiments', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Cooking oil', 'Oatmeal', 'Spices', 'Canned vegetables', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Macaroni and cheese', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Tomato sauce', 'Hot cocoa mix', 'Condiments', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Popcorn', 'Ketchup', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Boxed potatoes', 'Jello cups', 'Baking powder', 'Mustard', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Tomato sauce', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Salad dressing', 'Pancake mix and syrup', 'Jello cups', 'Instant coffee', 'Baking powder', 'Chips', 'Trail mix', 'Canned soup', 'Shelf-stable milk', 'Tomato sauce', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Popcorn', 'Canned soup', 'Pancake mix and syrup', 'Flour', 'Fruit cups', 'Instant mashed potatoes', 'Boxed stuffing mix', 'Peanut butter', 'Rice', 'Baking powder', 'Pasta', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Salad dressing', 'Vinegar']
# ['Pancake mix and syrup', 'Macaroni and cheese', 'Pudding cups', 'Evaporated milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Granola bars', 'Rice', 'Baking powder', 'Condiments', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Canned fruits', 'Nuts', 'Salad dressing', 'Vinegar']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Popcorn', 'Canned beans', 'Vanilla extract', 'Oatmeal', 'Spices', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Salad dressing', 'Jello cups', 'Vinegar', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Rice', 'Condiments', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Granola bars', 'Pasta', 'Tea bags', 'Evaporated milk', 'Oatmeal', 'Boxed potatoes', 'Sugar', 'Jello cups', 'Instant coffee', 'Mustard', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Canned chili', 'Popcorn', 'Evaporated milk', 'Canned beans', 'Jelly or jam', 'Canned tuna or chicken', 'Sugar', 'Salad dressing', 'Pancake mix and syrup', 'Flour', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Canned soup', 'Trail mix', 'Boxed cake mix', 'Macaroni and cheese', 'Rice', 'Tomato sauce', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Fruit cups', 'Pudding cups', 'Crackers', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Salad dressing', 'Jello cups', 'Nuts', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Rice', 'Hot cocoa mix', 'Canned fruits']
# ['Pudding cups', 'Tea bags', 'Popcorn', 'Crackers', 'Evaporated milk', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Spices', 'Baking soda', 'Boxed potatoes', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Nuts', 'Vinegar', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix', 'Salad dressing']
# ['Condensed milk', 'Pudding cups', 'Boxed stuffing mix', 'Granola bars', 'Canned chili', 'Tea bags', 'Popcorn', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Sugar', 'Salad dressing', 'Jello cups', 'Instant coffee', 'Vinegar', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Pretzels', 'Condiments', 'Canned fruits']
# ['Condensed milk', 'Pudding cups', 'Canned chili', 'Crackers', 'Dried fruit', 'Jelly or jam', 'Spices', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Jello cups', 'Instant coffee', 'Nuts', 'Vinegar', 'Chips', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Pretzels', 'Tomato sauce', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Oatmeal', 'Spices', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Canned soup', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Pretzels', 'Rice', 'Condiments']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Popcorn', 'Peanut butter', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Spices', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Tomato sauce', 'Rice', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Boxed stuffing mix', 'Pudding cups', 'Pasta', 'Popcorn', 'Canned beans', 'Dried fruit', 'Oatmeal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Vinegar', 'Rice', 'Condiments', 'Hot cocoa mix', 'Salad dressing']
# ['Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Tea bags', 'Popcorn', 'Canned beans', 'Vanilla extract', 'Baking soda', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Mustard', 'Vinegar', 'Canned soup', 'Trail mix', 'Shelf-stable milk', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Canned chili', 'Tea bags', 'Crackers', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Mustard', 'Vinegar', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Tea bags', 'Vanilla extract', 'Cooking oil', 'Canned vegetables', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Canned chili', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Instant coffee', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Rice', 'Tomato sauce', 'Hot cocoa mix', 'Canned fruits']
# ['Condensed milk', 'Boxed stuffing mix', 'Pasta', 'Tea bags', 'Popcorn', 'Ketchup', 'Evaporated milk', 'Canned beans', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Sugar', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Vinegar', 'Nuts', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Tomato sauce', 'Rice', 'Hot cocoa mix', 'Salad dressing']
# ['Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Ketchup', 'Evaporated milk', 'Cooking oil', 'Jelly or jam', 'Spices', 'Boxed potatoes', 'Baking soda', 'Sugar', 'Salad dressing', 'Pancake mix and syrup', 'Flour', 'Mustard', 'Nuts', 'Trail mix', 'Macaroni and cheese', 'Canned soup', 'Canned spaghetti or ravioli', 'Pretzels', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Popcorn', 'Peanut butter', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Sugar', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Trail mix', 'Pretzels', 'Condiments']
# ['Baking soda', 'Chips', 'Canned tuna or chicken', 'Trail mix', 'Macaroni and cheese', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Shelf-stable milk', 'Boxed stuffing mix', 'Hot cocoa mix', 'Pasta', 'Dried fruit', 'Mustard', 'Cooking oil', 'Vinegar']
# ['Mayonnaise', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Crackers', 'Ketchup', 'Peanut butter', 'Vanilla extract', 'Cooking oil', 'Salad dressing', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Nuts', 'Chips', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Canned chili', 'Tea bags', 'Crackers', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Mustard', 'Nuts', 'Vinegar', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Condiments', 'Salad dressing']
# ['Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Boxed potatoes', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Mustard', 'Chips', 'Canned soup', 'Trail mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Pudding cups', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Crackers', 'Evaporated milk', 'Cooking oil', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Nuts', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Pretzels', 'Tomato sauce', 'Condiments', 'Canned fruits']
# ['Tea bags', 'Salad dressing', 'Condensed milk', 'Macaroni and cheese', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Canned spaghetti or ravioli', 'Hot cocoa mix', 'Pasta', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Canned fruits', 'Canned vegetables']
# ['Mayonnaise', 'Fruit cups', 'Granola bars', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Cereal', 'Sugar', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Canned soup', 'Macaroni and cheese', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Canned chili', 'Tea bags', 'Crackers', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Boxed potatoes', 'Instant coffee', 'Baking powder', 'Nuts', 'Vinegar', 'Chips', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Pasta', 'Canned chili', 'Popcorn', 'Dried fruit', 'Cooking oil', 'Boxed potatoes', 'Baking soda', 'Salad dressing', 'Instant mashed potatoes', 'Baking powder', 'Nuts', 'Vinegar', 'Canned soup', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Pretzels', 'Canned fruits']
# ['Condensed milk', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Dried fruit', 'Vanilla extract', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Sugar', 'Canned tuna or chicken', 'Instant mashed potatoes', 'Instant coffee', 'Vinegar', 'Nuts', 'Chips', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Salad dressing']
# ['Boxed stuffing mix', 'Pudding cups', 'Pasta', 'Canned chili', 'Tea bags', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Trail mix', 'Tomato sauce', 'Condiments', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Pudding cups', 'Pasta', 'Popcorn', 'Crackers', 'Ketchup', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Spices', 'Cereal', 'Canned vegetables', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Baking powder', 'Chips', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Condiments', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Pasta', 'Canned chili', 'Tea bags', 'Ketchup', 'Evaporated milk', 'Dried fruit', 'Jelly or jam', 'Cereal', 'Canned vegetables', 'Baking soda', 'Flour', 'Jello cups', 'Baking powder', 'Nuts', 'Chips', 'Macaroni and cheese', 'Condiments', 'Salad dressing']
# ['Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Jello cups', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Trail mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Condiments', 'Canned fruits']
# ['Fruit cups', 'Pudding cups', 'Granola bars', 'Canned chili', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Vinegar', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Macaroni and cheese', 'Rice', 'Condiments', 'Salad dressing']
# ['Pudding cups', 'Tea bags', 'Ketchup', 'Evaporated milk', 'Dried fruit', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Vinegar', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Tomato sauce', 'Pretzels', 'Rice', 'Condiments', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Canned chili', 'Tea bags', 'Popcorn', 'Ketchup', 'Peanut butter', 'Vanilla extract', 'Oatmeal', 'Spices', 'Baking soda', 'Canned tuna or chicken', 'Boxed potatoes', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Rice', 'Condiments', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Granola bars', 'Pasta', 'Canned chili', 'Crackers', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Oatmeal', 'Boxed potatoes', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Canned chili', 'Crackers', 'Ketchup', 'Canned beans', 'Spices', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Salad dressing', 'Pancake mix and syrup', 'Flour', 'Instant coffee', 'Baking powder', 'Nuts', 'Macaroni and cheese', 'Shelf-stable milk', 'Tomato sauce', 'Pretzels', 'Rice', 'Condiments', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Canned chili', 'Tea bags', 'Popcorn', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Mustard', 'Vinegar', 'Nuts', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Condiments', 'Hot cocoa mix']
# ['Tea bags', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Chips', 'Macaroni and cheese', 'Rice', 'Tomato sauce', 'Pretzels', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Ketchup', 'Evaporated milk', 'Canned beans', 'Jelly or jam', 'Oatmeal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Baking soda', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Trail mix', 'Canned soup', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Boxed potatoes', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Crackers', 'Boxed stuffing mix', 'Pudding cups', 'Ketchup', 'Pretzels', 'Granola bars', 'Rice', 'Condiments', 'Canned beans', 'Jelly or jam', 'Cereal', 'Vinegar']
# ['Tea bags', 'Canned tuna or chicken', 'Chips', 'Pancake mix and syrup', 'Crackers', 'Fruit cups', 'Shelf-stable milk', 'Ketchup', 'Canned spaghetti or ravioli', 'Boxed stuffing mix', 'Condiments', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Tea bags', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Nuts', 'Vinegar', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Rice', 'Tomato sauce', 'Hot cocoa mix', 'Canned fruits']
# ['Tea bags', 'Baking soda', 'Chips', 'Sugar', 'Fruit cups', 'Jello cups', 'Pudding cups', 'Ketchup', 'Instant coffee', 'Instant mashed potatoes', 'Baking powder', 'Pasta', 'Canned beans', 'Mustard', 'Vanilla extract', 'Jelly or jam', 'Canned fruits', 'Vinegar']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Canned chili', 'Popcorn', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Baking soda', 'Instant coffee', 'Baking powder', 'Mustard', 'Chips', 'Trail mix', 'Rice', 'Tomato sauce', 'Pretzels', 'Salad dressing']
# ['Boxed potatoes', 'Chips', 'Mayonnaise', 'Sugar', 'Trail mix', 'Macaroni and cheese', 'Crackers', 'Boxed cake mix', 'Shelf-stable milk', 'Jello cups', 'Canned spaghetti or ravioli', 'Evaporated milk', 'Granola bars', 'Baking powder', 'Dried fruit', 'Oatmeal', 'Salad dressing', 'Nuts']
# ['Condensed milk', 'Popcorn', 'Peanut butter', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Spices', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Baking soda', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Condiments', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Popcorn', 'Crackers', 'Evaporated milk', 'Peanut butter', 'Cooking oil', 'Oatmeal', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Trail mix', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Boxed potatoes', 'Popcorn', 'Mayonnaise', 'Chips', 'Baking soda', 'Pancake mix and syrup', 'Crackers', 'Boxed cake mix', 'Boxed stuffing mix', 'Jello cups', 'Pasta', 'Canned beans', 'Jelly or jam', 'Oatmeal', 'Nuts', 'Cereal', 'Vinegar']
# ['Fruit cups', 'Pudding cups', 'Pasta', 'Canned chili', 'Ketchup', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Oatmeal', 'Spices', 'Cereal', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Hot cocoa mix', 'Salad dressing']
# ['Condensed milk', 'Pudding cups', 'Boxed stuffing mix', 'Granola bars', 'Canned chili', 'Popcorn', 'Crackers', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Sugar', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Pretzels', 'Condiments', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Crackers', 'Ketchup', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Oatmeal', 'Spices', 'Cereal', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Rice', 'Pretzels', 'Condiments', 'Salad dressing']
# ['Pudding cups', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Tea bags', 'Ketchup', 'Peanut butter', 'Evaporated milk', 'Vanilla extract', 'Cooking oil', 'Baking soda', 'Canned tuna or chicken', 'Flour', 'Jello cups', 'Instant coffee', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned soup', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Tomato sauce', 'Rice', 'Condiments', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Pudding cups', 'Canned chili', 'Crackers', 'Ketchup', 'Peanut butter', 'Jelly or jam', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Mustard', 'Vinegar', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Rice', 'Pretzels', 'Canned fruits']
# ['Condensed milk', 'Granola bars', 'Canned chili', 'Crackers', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Jelly or jam', 'Baking soda', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Vinegar', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Shelf-stable milk', 'Condiments']
# ['Boxed potatoes', 'Chips', 'Baking soda', 'Trail mix', 'Pancake mix and syrup', 'Condensed milk', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Crackers', 'Macaroni and cheese', 'Pretzels', 'Rice', 'Hot cocoa mix', 'Cooking oil', 'Cereal']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Spices', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Nuts', 'Vinegar', 'Chips', 'Trail mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Tomato sauce', 'Canned fruits']
# ['Tea bags', 'Chips', 'Condensed milk', 'Trail mix', 'Boxed cake mix', 'Crackers', 'Flour', 'Ketchup', 'Instant mashed potatoes', 'Instant coffee', 'Tomato sauce', 'Pretzels', 'Granola bars', 'Hot cocoa mix', 'Pudding cups', 'Oatmeal', 'Salad dressing', 'Vinegar']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Jello cups', 'Baking powder', 'Mustard', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Macaroni and cheese', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Hot cocoa mix', 'Canned fruits']
# ['Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Granola bars', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Canned tuna or chicken', 'Flour', 'Jello cups', 'Instant coffee', 'Baking powder', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Rice', 'Pretzels', 'Condiments']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Tea bags', 'Popcorn', 'Crackers', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Cereal', 'Boxed potatoes', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Nuts', 'Chips', 'Macaroni and cheese', 'Pretzels', 'Condiments']
# ['Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Canned chili', 'Popcorn', 'Ketchup', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Spices', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Vinegar', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Hot cocoa mix', 'Condiments', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Canned soup', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Hot cocoa mix', 'Canned fruits']
# ['Popcorn', 'Mayonnaise', 'Sugar', 'Canned chili', 'Canned soup', 'Cooking oil', 'Instant mashed potatoes', 'Ketchup', 'Evaporated milk', 'Rice', 'Baking powder', 'Mustard', 'Canned vegetables', 'Vanilla extract', 'Cereal', 'Salad dressing', 'Nuts']
# ['Fruit cups', 'Boxed stuffing mix', 'Canned chili', 'Crackers', 'Ketchup', 'Dried fruit', 'Oatmeal', 'Spices', 'Cereal', 'Boxed potatoes', 'Pancake mix and syrup', 'Flour', 'Instant coffee', 'Baking powder', 'Mustard', 'Trail mix', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Mayonnaise', 'Pudding cups', 'Pasta', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Baking powder', 'Mustard', 'Nuts', 'Chips', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Tea bags', 'Crackers', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Cereal', 'Canned vegetables', 'Jello cups', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Trail mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Canned beans', 'Oatmeal', 'Baking soda', 'Canned tuna or chicken', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Trail mix', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Canned fruits', 'Salad dressing']
# ['Canned soup', 'Boxed cake mix', 'Jello cups', 'Instant mashed potatoes', 'Ketchup', 'Peanut butter', 'Instant coffee', 'Tomato sauce', 'Hot cocoa mix', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned chili', 'Vinegar']
# ['Mayonnaise', 'Boxed stuffing mix', 'Tea bags', 'Crackers', 'Evaporated milk', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Baking powder', 'Mustard', 'Nuts', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Tomato sauce', 'Salad dressing']
# ['Granola bars', 'Canned chili', 'Crackers', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Vinegar', 'Chips', 'Boxed cake mix', 'Shelf-stable milk', 'Pretzels', 'Condiments', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Tea bags', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Canned vegetables', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Trail mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Pretzels', 'Canned fruits']
# ['Condensed milk', 'Pudding cups', 'Boxed stuffing mix', 'Pasta', 'Crackers', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Salad dressing', 'Jello cups', 'Baking powder', 'Chips', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Granola bars', 'Pasta', 'Canned chili', 'Popcorn', 'Oatmeal', 'Spices', 'Cereal', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Pretzels', 'Rice', 'Condiments', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Tea bags', 'Popcorn', 'Crackers', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Boxed potatoes', 'Salad dressing', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Nuts', 'Canned soup', 'Rice', 'Tomato sauce', 'Condiments', 'Canned fruits']
# ['Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Popcorn', 'Evaporated milk', 'Dried fruit', 'Cooking oil', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Baking soda', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Canned soup', 'Trail mix', 'Canned spaghetti or ravioli', 'Hot cocoa mix']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Jelly or jam', 'Oatmeal', 'Spices', 'Canned vegetables', 'Baking soda', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Vinegar', 'Nuts', 'Chips', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Macaroni and cheese', 'Shelf-stable milk', 'Rice']
# ['Boxed stuffing mix', 'Granola bars', 'Popcorn', 'Crackers', 'Ketchup', 'Peanut butter', 'Evaporated milk', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Boxed potatoes', 'Canned tuna or chicken', 'Flour', 'Jello cups', 'Baking powder', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Trail mix', 'Shelf-stable milk', 'Tomato sauce', 'Rice', 'Condiments', 'Hot cocoa mix']
# ['Condensed milk', 'Boxed stuffing mix', 'Granola bars', 'Popcorn', 'Crackers', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Cereal', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Baking soda', 'Flour', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Canned soup', 'Pretzels', 'Tomato sauce', 'Condiments']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cereal', 'Canned vegetables', 'Flour', 'Instant coffee', 'Baking powder', 'Nuts', 'Macaroni and cheese', 'Rice', 'Tomato sauce', 'Condiments', 'Hot cocoa mix']
# ['Condensed milk', 'Boxed stuffing mix', 'Pasta', 'Popcorn', 'Crackers', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Oatmeal', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Salad dressing', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Chips', 'Trail mix', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Rice', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Baking soda', 'Boxed potatoes', 'Sugar', 'Chips', 'Canned chili', 'Condensed milk', 'Pancake mix and syrup', 'Trail mix', 'Canned soup', 'Boxed stuffing mix', 'Ketchup', 'Flour', 'Dried fruit', 'Cooking oil', 'Oatmeal', 'Cereal', 'Canned fruits', 'Nuts']
# ['Condensed milk', 'Pudding cups', 'Canned chili', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Dried fruit', 'Spices', 'Cereal', 'Baking soda', 'Sugar', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Canned soup', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Pretzels', 'Condiments']
# ['Pasta', 'Tea bags', 'Popcorn', 'Crackers', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Canned tuna or chicken', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Vinegar', 'Nuts', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Condiments', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Canned chili', 'Crackers', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Boxed potatoes', 'Instant mashed potatoes', 'Canned soup', 'Trail mix', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Canned chili', 'Tea bags', 'Crackers', 'Cooking oil', 'Jelly or jam', 'Spices', 'Cereal', 'Baking soda', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Nuts', 'Chips', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pasta', 'Canned chili', 'Popcorn', 'Dried fruit', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Instant coffee', 'Baking powder', 'Vinegar', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Trail mix', 'Pretzels', 'Tomato sauce', 'Rice', 'Condiments', 'Salad dressing']
# ['Mayonnaise', 'Pasta', 'Canned chili', 'Popcorn', 'Dried fruit', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Jello cups', 'Baking powder', 'Mustard', 'Nuts', 'Trail mix', 'Boxed cake mix', 'Shelf-stable milk', 'Tomato sauce', 'Condiments', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Granola bars', 'Tea bags', 'Ketchup', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Instant coffee', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Canned soup', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Rice', 'Pretzels', 'Tomato sauce', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Granola bars', 'Evaporated milk', 'Cooking oil', 'Jelly or jam', 'Baking soda', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Canned soup', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Condiments', 'Hot cocoa mix', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Pudding cups', 'Popcorn', 'Crackers', 'Peanut butter', 'Vanilla extract', 'Spices', 'Cereal', 'Canned vegetables', 'Jello cups', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Rice', 'Tomato sauce', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Boxed stuffing mix', 'Granola bars', 'Popcorn', 'Crackers', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Canned vegetables', 'Baking soda', 'Salad dressing', 'Flour', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Tea bags', 'Popcorn', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Baking powder', 'Chips', 'Macaroni and cheese', 'Pretzels', 'Tomato sauce', 'Condiments', 'Canned fruits', 'Salad dressing']
# ['Fruit cups', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Canned vegetables', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Rice', 'Tomato sauce', 'Hot cocoa mix']
# ['Mayonnaise', 'Fruit cups', 'Granola bars', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Boxed potatoes', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Vinegar', 'Nuts', 'Chips', 'Macaroni and cheese', 'Rice', 'Pretzels', 'Condiments', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Crackers', 'Ketchup', 'Peanut butter', 'Cooking oil', 'Oatmeal', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Canned tuna or chicken', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Vinegar', 'Chips', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Condiments', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Pudding cups', 'Pasta', 'Tea bags', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Spices', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Nuts', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Hot cocoa mix', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Granola bars', 'Canned chili', 'Popcorn', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Boxed potatoes', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Salad dressing']
# ['Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Mayonnaise', 'Baking soda', 'Canned soup', 'Pancake mix and syrup', 'Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Shelf-stable milk', 'Baking powder', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Canned vegetables', 'Nuts']
# ...
# ['Mayonnaise', 'Boxed stuffing mix', 'Pasta', 'Tea bags', 'Popcorn', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Baking soda', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Pretzels', 'Hot cocoa mix']
# ['Mayonnaise', 'Condensed milk', 'Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Crackers', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Oatmeal', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Flour', 'Jello cups', 'Instant coffee', 'Nuts', 'Vinegar', 'Chips', 'Trail mix', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Rice', 'Tomato sauce', 'Condiments']
# ['Tea bags', 'Boxed potatoes', 'Canned soup', 'Pancake mix and syrup', 'Flour', 'Boxed cake mix', 'Instant mashed potatoes', 'Ketchup', 'Canned spaghetti or ravioli', 'Crackers', 'Baking powder', 'Pasta', 'Condiments', 'Mustard', 'Canned fruits', 'Cereal', 'Salad dressing', 'Nuts']
# ['Tea bags', 'Boxed potatoes', 'Sugar', 'Mayonnaise', 'Boxed cake mix', 'Shelf-stable milk', 'Boxed stuffing mix', 'Instant mashed potatoes', 'Ketchup', 'Pretzels', 'Baking powder', 'Condiments', 'Dried fruit', 'Canned beans', 'Jelly or jam', 'Canned fruits', 'Vinegar']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Trail mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Pretzels', 'Canned fruits', 'Salad dressing']
# ['Condensed milk', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Dried fruit', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Baking soda', 'Boxed potatoes', 'Salad dressing', 'Jello cups', 'Instant coffee', 'Baking powder', 'Mustard', 'Nuts', 'Trail mix', 'Shelf-stable milk', 'Pretzels', 'Tomato sauce', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Popcorn', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cereal', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Canned tuna or chicken', 'Jello cups', 'Mustard', 'Vinegar', 'Nuts', 'Canned soup', 'Rice', 'Tomato sauce', 'Condiments']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pudding cups', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Sugar', 'Salad dressing', 'Flour', 'Jello cups', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Trail mix', 'Canned soup', 'Shelf-stable milk', 'Pretzels', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pudding cups', 'Popcorn', 'Crackers', 'Peanut butter', 'Cooking oil', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Nuts', 'Chips', 'Trail mix', 'Shelf-stable milk', 'Rice', 'Pretzels', 'Condiments', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Popcorn', 'Ketchup', 'Peanut butter', 'Evaporated milk', 'Canned beans', 'Jelly or jam', 'Spices', 'Cereal', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Boxed cake mix', 'Tomato sauce', 'Pretzels', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Granola bars', 'Tea bags', 'Crackers', 'Ketchup', 'Evaporated milk', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Rice', 'Hot cocoa mix', 'Condiments']
# ['Mayonnaise', 'Condensed milk', 'Boxed stuffing mix', 'Granola bars', 'Popcorn', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Baking soda', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Nuts', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Rice', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Pudding cups', 'Canned chili', 'Popcorn', 'Crackers', 'Evaporated milk', 'Canned beans', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Flour', 'Jello cups', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Granola bars', 'Pasta', 'Crackers', 'Ketchup', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Canned vegetables', 'Salad dressing', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Vinegar', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Canned soup', 'Canned spaghetti or ravioli', 'Rice', 'Pretzels', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Condensed milk', 'Granola bars', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Vanilla extract', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Flour', 'Jello cups', 'Instant coffee', 'Mustard', 'Nuts', 'Vinegar', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Tomato sauce', 'Rice', 'Condiments', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Crackers', 'Ketchup', 'Evaporated milk', 'Canned beans', 'Dried fruit', 'Jelly or jam', 'Spices', 'Canned vegetables', 'Baking soda', 'Boxed potatoes', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned soup', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pasta', 'Tea bags', 'Crackers', 'Ketchup', 'Vanilla extract', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant coffee', 'Nuts', 'Chips', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Boxed stuffing mix', 'Pudding cups', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Oatmeal', 'Baking soda', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Mustard', 'Nuts', 'Chips', 'Trail mix', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Tomato sauce', 'Pretzels', 'Hot cocoa mix', 'Salad dressing']
# ['Pudding cups', 'Pasta', 'Canned chili', 'Tea bags', 'Ketchup', 'Peanut butter', 'Canned beans', 'Dried fruit', 'Cooking oil', 'Oatmeal', 'Cereal', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Flour', 'Instant coffee', 'Baking powder', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Pretzels', 'Rice', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pasta', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Mustard', 'Nuts', 'Vinegar', 'Chips', 'Canned soup', 'Trail mix', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Pretzels', 'Condiments']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Boxed stuffing mix', 'Canned chili', 'Crackers', 'Ketchup', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Baking soda', 'Pancake mix and syrup', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Baking powder', 'Nuts', 'Canned soup', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Pretzels', 'Condiments', 'Canned fruits', 'Salad dressing']
# ['Pudding cups', 'Granola bars', 'Popcorn', 'Peanut butter', 'Evaporated milk', 'Cooking oil', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Jello cups', 'Instant mashed potatoes', 'Mustard', 'Nuts', 'Canned soup', 'Macaroni and cheese', 'Trail mix', 'Shelf-stable milk', 'Pretzels', 'Condiments', 'Hot cocoa mix', 'Canned fruits']
# ['Mayonnaise', 'Condensed milk', 'Pudding cups', 'Canned chili', 'Tea bags', 'Crackers', 'Evaporated milk', 'Dried fruit', 'Cooking oil', 'Jelly or jam', 'Cereal', 'Canned tuna or chicken', 'Sugar', 'Flour', 'Instant mashed potatoes', 'Baking powder', 'Mustard', 'Vinegar', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Tomato sauce', 'Hot cocoa mix', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pasta', 'Tea bags', 'Popcorn', 'Ketchup', 'Evaporated milk', 'Dried fruit', 'Canned beans', 'Jelly or jam', 'Cereal', 'Canned vegetables', 'Baking soda', 'Pancake mix and syrup', 'Instant coffee', 'Vinegar', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Rice', 'Hot cocoa mix', 'Condiments', 'Canned fruits']
# ['Mayonnaise', 'Pasta', 'Popcorn', 'Crackers', 'Peanut butter', 'Evaporated milk', 'Dried fruit', 'Jelly or jam', 'Oatmeal', 'Cereal', 'Canned vegetables', 'Baking soda', 'Sugar', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Trail mix', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Canned fruits', 'Salad dressing']
# ['Fruit cups', 'Popcorn', 'Crackers', 'Peanut butter', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Cereal', 'Canned vegetables', 'Canned tuna or chicken', 'Pancake mix and syrup', 'Flour', 'Mustard', 'Vinegar', 'Trail mix', 'Shelf-stable milk', 'Rice', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Granola bars', 'Pasta', 'Popcorn', 'Evaporated milk', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Boxed potatoes', 'Flour', 'Jello cups', 'Nuts', 'Vinegar', 'Trail mix', 'Canned soup', 'Shelf-stable milk', 'Canned fruits', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Pasta', 'Popcorn', 'Evaporated milk', 'Peanut butter', 'Dried fruit', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Cereal', 'Baking soda', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Pretzels', 'Rice', 'Hot cocoa mix', 'Salad dressing']
# ['Pudding cups', 'Tea bags', 'Ketchup', 'Jelly or jam', 'Cereal', 'Canned vegetables', 'Baking soda', 'Flour', 'Jello cups', 'Instant coffee', 'Mustard', 'Nuts', 'Vinegar', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Rice', 'Canned fruits']
# ['Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Crackers', 'Ketchup', 'Canned beans', 'Vanilla extract', 'Spices', 'Cereal', 'Pancake mix and syrup', 'Instant coffee', 'Mustard', 'Chips', 'Shelf-stable milk', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Salad dressing']
# ['Mayonnaise', 'Fruit cups', 'Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Crackers', 'Ketchup', 'Peanut butter', 'Dried fruit', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Jelly or jam', 'Spices', 'Boxed potatoes', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Baking powder', 'Vinegar', 'Nuts', 'Chips', 'Trail mix', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Pretzels', 'Rice', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Pasta', 'Canned chili', 'Tea bags', 'Crackers', 'Ketchup', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Cooking oil', 'Oatmeal', 'Spices', 'Cereal', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Canned soup', 'Boxed cake mix', 'Shelf-stable milk', 'Rice', 'Tomato sauce', 'Pretzels', 'Hot cocoa mix', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pasta', 'Canned chili', 'Tea bags', 'Popcorn', 'Crackers', 'Ketchup', 'Evaporated milk', 'Peanut butter', 'Canned beans', 'Vanilla extract', 'Oatmeal', 'Spices', 'Boxed potatoes', 'Canned tuna or chicken', 'Sugar', 'Pancake mix and syrup', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Mustard', 'Vinegar', 'Trail mix', 'Canned soup', 'Boxed cake mix', 'Macaroni and cheese', 'Canned spaghetti or ravioli', 'Rice', 'Hot cocoa mix']
# ['Boxed stuffing mix', 'Granola bars', 'Canned chili', 'Tea bags', 'Popcorn', 'Ketchup', 'Dried fruit', 'Jelly or jam', 'Spices', 'Cereal', 'Canned vegetables', 'Baking soda', 'Sugar', 'Jello cups', 'Instant coffee', 'Mustard', 'Vinegar', 'Chips', 'Trail mix', 'Boxed cake mix', 'Tomato sauce', 'Salad dressing']
# ['Condensed milk', 'Fruit cups', 'Pudding cups', 'Canned chili', 'Popcorn', 'Dried fruit', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Baking soda', 'Canned tuna or chicken', 'Sugar', 'Salad dressing', 'Flour', 'Instant mashed potatoes', 'Instant coffee', 'Nuts', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Rice', 'Canned fruits']
# ['Mayonnaise', 'Pudding cups', 'Boxed stuffing mix', 'Granola bars', 'Popcorn', 'Ketchup', 'Evaporated milk', 'Canned beans', 'Vanilla extract', 'Jelly or jam', 'Spices', 'Boxed potatoes', 'Pancake mix and syrup', 'Flour', 'Mustard', 'Vinegar', 'Chips', 'Trail mix', 'Macaroni and cheese', 'Boxed cake mix', 'Canned soup', 'Shelf-stable milk', 'Pretzels']
# ['Mayonnaise', 'Granola bars', 'Tea bags', 'Crackers', 'Evaporated milk', 'Vanilla extract', 'Spices', 'Cereal', 'Canned vegetables', 'Boxed potatoes', 'Baking soda', 'Flour', 'Jello cups', 'Instant mashed potatoes', 'Instant coffee', 'Baking powder', 'Vinegar', 'Canned soup', 'Salad dressing']
# ['Mayonnaise', 'Condensed milk', 'Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Pasta', 'Tea bags', 'Crackers', 'Canned beans', 'Vanilla extract', 'Oatmeal', 'Spices', 'Baking soda', 'Boxed potatoes', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Instant mashed potatoes', 'Vinegar', 'Nuts', 'Chips', 'Canned soup', 'Macaroni and cheese', 'Boxed cake mix', 'Canned spaghetti or ravioli', 'Tomato sauce', 'Pretzels', 'Condiments', 'Salad dressing']
# ['Fruit cups', 'Boxed stuffing mix', 'Pudding cups', 'Granola bars', 'Pasta', 'Tea bags', 'Popcorn', 'Dried fruit', 'Jelly or jam', 'Oatmeal', 'Spices', 'Cereal', 'Baking soda', 'Sugar', 'Pancake mix and syrup', 'Jello cups', 'Mustard', 'Nuts', 'Vinegar', 'Trail mix', 'Canned soup', 'Macaroni and cheese', 'Shelf-stable milk', 'Pretzels', 'Rice', 'Hot cocoa mix']
# ['Mayonnaise', 'Canned soup', 'Condensed milk', 'Boxed cake mix', 'Jello cups', 'Boxed stuffing mix', 'Evaporated milk', 'Granola bars', 'Pasta', 'Dried fruit', 'Canned beans', 'Spices', 'Cereal', 'Nuts']
# <ipython-input-254-e5cfe4068f75>:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_items_df = top_items_df.append({"PantryID": pantry_id, "TopItems": top_items_str}, ignore_index=True)
